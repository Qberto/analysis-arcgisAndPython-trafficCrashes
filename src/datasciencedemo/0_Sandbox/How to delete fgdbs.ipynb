# %% [markdown]
# ## How to delete file geodatabases (and other directories containing files) from a Hosted Notebook

# %% [markdown]
# ## Using a magic command

# %% [markdown]
# Example File Geodatabase path

# %%
fgdb = r"/arcgis/home/anieto/workspace/jo_fgdb.gdb"

# %%
# !rm -r /arcgis/home/anieto/workspace/jo_fgdb.gdb

# %% [markdown]
# ## Using the shutil module

# %% [markdown]
# Example File Geodatabase path

# %%
fgdb2 = r"/arcgis/home/anieto/workspace/jo_fgdb2.gdb"

# %%
import shutil
shutil.rmtree(fgdb2)
